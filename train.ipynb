# %%
import pandas as pd
import lightgbm as lgb
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import joblib

from feature_engineering import process_match_string, process_league
from train import train_and_save_model, predict_game_kda

# %%
league = "TCL"
df_features = process_league(league)

# %%
model = train_and_save_model(df_features)
# Out:
# Fitting 5 folds for each of 1536 candidates, totalling 7680 fits
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000195 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1119
# [LightGBM] [Info] Number of data points in the train set: 630, number of used features: 11
# [LightGBM] [Info] Start training from score 3.282540
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
predicted_kda = predict_game_kda("MISA", "BGT", df_features)
# Out:
# Mihile: [5.65783334 2.76978365 6.04289611]
# Zanzarah: [ 2.99738798  3.24727943 11.10717962]
# Callme: [ 3.65164584  2.9054897  11.45096292]
# Lens: [7.02925952 3.12241601 7.17840266]
# Batuuu: [ 1.50736842  3.51674328 13.8338044 ]
# Kaori: [4.36564582 3.816048   6.91255108]
# NuQ: [3.06414914 3.82369942 7.30125066]
# Typhoon: [3.62242834 2.88215588 8.55831395]
# Jool: [ 3.43977987  2.82948661 10.18994663]
# ToongE: [4.45769487 2.96956543 7.03326531]
# Patch: [ 3.03081078  2.92543143 11.03786983]
